# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
img_raw = cv2.imread('./image/mandrill_colour.png')

# %%
np.shape(img_raw)
# Out:
# (288, 288, 3)

# %%
type(img_raw)
# Out:
# numpy.ndarray

# %%
plt.imshow(img_raw)

# %%
type(img_raw)
# Out:
# numpy.ndarray

# %%
img_raw.shape
# Out:
# (288, 288, 3)

# %%
# img_rgb = cv2.cvtColor(img_raw, cv2.COLOR_BGR2RGB)
plt.imshow(img_raw)

# %%
import cv2
img = cv2.imread('./image/mandrill_colour.png')
while Truedd:
    cv2.imshow('mandrill',img)

    if cv2.waitKey(1) & 0xFF == 27:
        break


cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-bbe1819d15e6> in <module>
#       4     cv2.imshow('mandrill',img)
#       5
# ----> 6     if cv2.waitKey(1) & 0xFF == 27:
#       7         break
#       8
#
# KeyboardInterrupt:

# %%
cv2.imwrite('./image/final_image.png',img)
# Out:
# True

# %%
image_blank = np.zeros(shape=(512,512,1),dtype=np.int16)

# %%
plt.imshow(image_blank)

# %%
np.int16
# Out:
# numpy.int16

# %%
image_blank = np.zeros(shape=(500,500,3),dtype=np.int16)
plt.imshow(cv2.line(image_blank,(100,100),(100,300),(255,160,255),3))
plt.imshow(cv2.line(image_blank,(100,300),(400,300),(255,160,255),3))
plt.imshow(cv2.line(image_blank,(100,100),(400,100),(255,160,255),3))
plt.imshow(cv2.line(image_blank,(400,100),(400,300),(255,160,255),3))

# %%
rectangle= cv2.rectangle(image_blank,(384,0),(510,128),(255,255,255),5)
plt.imshow(rectangle)

# %%
image_blank = np.zeros(shape=(500,500,3),dtype=np.int16)
img = cv2.circle(image_blank,(447,63), 100, (255,255,255), -1) 
plt.imshow(img)

# %%
image_blank = np.zeros(shape=(500,500,3),dtype=np.int16)
font = cv2.FONT_HERSHEY_SIMPLEX
text = cv2.putText(image_blank,'OpenCV',(10,500), font, 4,(255,255,255),2,cv2.LINE_AA)
plt.imshow(text)

# %%
image_black = np.zeros(shape=(500,500,3))
plt.imshow(cv2.putText(image_black,"blk",(10,500),font, 4,(255,255,255),2,cv2.LINE_AA))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
image_black = np.zeros(shape=(500,500,3))
plt.imshow(cv2.putText(image_black,"black_photo",(10,500),font, 2,(255,255,255),2,cv2.LINE_AA))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
#Loading the image to be tested
test_image = cv2.imread('./image/baby1.jpeg')

# #Converting to grayscale
test_image_gray = cv2.cvtColor(test_image, cv2.COLOR_BGR2GRAY)

# # Displaying the grayscale image
plt.imshow(test_image_gray, cmap='gray')
# Since we know that OpenCV loads an image in BGR format, so we need to co

# %%
def color_image_change(image):
    return cv2.cvtColor(image, cv2.COLOR_BRG2RGB)

# %%
haar_cascade_face = cv2.CascadeClassifier('data/haarcascade/haarcascade_frontalface_default.xml')

# %%
haar_cascade_face
# Out:
# <CascadeClassifier 0x7fb13bb2bd70>

# %%
def detect_faces(cascade, test_image, scaleFactor = 1.1):
    # create a copy of the image to prevent any changes to the original one.
    image_copy = test_image.copy()

    #convert the test image to gray scale as opencv face detector expects gray images
    gray_image = cv2.cvtColor(image_copy, cv2.COLOR_BGR2GRAY)

    # Applying the haar classifier to detect faces
    faces_rect = cascade.detectMultiScale(gray_image, scaleFactor=scaleFactor, minNeighbors=5)

    for (x, y, w, h) in faces_rect:
        cv2.rectangle(image_copy, (x, y), (x+w, y+h), (0, 255, 0), 15)

    return image_copy
